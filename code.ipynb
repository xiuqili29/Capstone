# %% [markdown]
# Capstone

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
df1 = pd.read_csv("D:/ucla/409/Capstone/data/CNYUSD=X.csv")
df2 = pd.read_csv("D:/ucla/409/Capstone/data/JPYUSD=X.csv")
df3 = pd.read_csv("D:/ucla/409/Capstone/data/cpi_chn.csv")
df4 = pd.read_csv("D:/ucla/409/Capstone/data/cpi_jap.csv")
df5 = pd.read_csv("D:/ucla/409/Capstone/data/cpi_us.csv")
df6 = pd.read_csv("D:/ucla/409/Capstone/data/iip_chn.csv")
df7 = pd.read_csv("D:/ucla/409/Capstone/data/iip_jap.csv")
df8 = pd.read_csv("D:/ucla/409/Capstone/data/iip_us.csv")
df9 = pd.read_csv("D:/ucla/409/Capstone/data/irr_chn.csv")
df10 = pd.read_csv("D:/ucla/409/Capstone/data/irr_jap.csv")
df11 = pd.read_csv("D:/ucla/409/Capstone/data/irr_us.csv")
df12 = pd.read_csv("D:/ucla/409/Capstone/data/m1_chn.csv")
df13 = pd.read_csv("D:/ucla/409/Capstone/data/m1_jap.csv")
df14 = pd.read_csv("D:/ucla/409/Capstone/data/m1_us.csv")
df15 = pd.read_csv("D:/ucla/409/Capstone/data/nt_us.csv")
df16 = pd.read_csv("D:/ucla/409/Capstone/data/nt_chn.csv")
df17 = pd.read_csv("D:/ucla/409/Capstone/data/nt_jap.csv")
df18 = pd.read_csv("D:/ucla/409/Capstone/data/tr_us.csv")
df19 = pd.read_csv("D:/ucla/409/Capstone/data/tr_chn.csv")
df20 = pd.read_csv("D:/ucla/409/Capstone/data/tr_jap.csv")
df21 = pd.read_csv("D:/ucla/409/Capstone/data/stock_us.csv")
df22 = pd.read_csv("D:/ucla/409/Capstone/data/stock_chn.csv")
df23 = pd.read_csv("D:/ucla/409/Capstone/data/stock_jap.csv")

# %%
y1 = df1[['DATE','CNYUSD']]
d1 = pd.merge(y1, df3, on = 'DATE', how= 'left') 
d1 = pd.merge(d1, df5, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df6, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df8, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df9, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df11, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df12, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df14, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df15, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df16, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df18, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df19, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df21, on = 'DATE', how= 'left')
d1 = pd.merge(d1, df22, on = 'DATE', how= 'left')


print(d1)
# Out:
#          DATE    CNYUSD     cpi_chn   cpi_us  iip_chn    iip_us  irr_chn  \
# 0    2002/1/1  0.120824   71.061305  177.700    118.6   88.6706     3.24
# 1    2002/2/1  0.120824   71.842980  178.000    102.7   88.6723     2.70
# 2    2002/3/1  0.120811   70.909021  178.500    110.9   89.3624     2.70
# 3    2002/4/1  0.120812   70.696294  179.300    112.1   89.7933     2.70
# 4    2002/5/1  0.120824   70.484205  179.500    112.9   90.1629     2.70
# ..        ...       ...         ...      ...      ...       ...      ...
# 241  2022/2/1  0.158328  114.334737  284.182      NaN  103.6341      NaN
# 242  2022/3/1  0.157575         NaN  287.708      NaN  104.5853      NaN
# 243  2022/4/1  0.151343         NaN      NaN      NaN       NaN      NaN
# 244  2022/5/1  0.151345         NaN      NaN      NaN       NaN      NaN
# 245  2022/5/5  0.150297         NaN      NaN      NaN       NaN      NaN
#
#        irr_us        m1_chn    m1_us         nt_us        nt_chn  \
# ...

# %%
y2 = df2[['DATE','JPYUSD']]
d2 = pd.merge(y2, df4, on = 'DATE', how= 'left') 
d2 = pd.merge(d2, df5, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df7, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df8, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df9, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df11, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df10, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df14, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df13, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df17, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df18, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df20, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df21, on = 'DATE', how= 'left')
d2 = pd.merge(d2, df23, on = 'DATE', how= 'left')
print(d2)
# Out:
#          DATE    JPYUSD     cpi_jap   cpi_us     iip_jap    iip_us  irr_chn  \
# 0    2002/2/1  0.007493   97.022143  178.000   94.044321   88.6723      2.7
# 1    2002/3/1  0.007524   97.225757  178.500  106.912415   89.3624      2.7
# 2    2002/4/1  0.007780   97.531178  179.300   94.687725   89.7933      2.7
# 3    2002/5/1  0.008061   97.836600  179.500   95.652832   90.1629      2.7
# 4    2002/6/1  0.008367   97.734793  179.600   99.298792   90.9078      2.7
# ..        ...       ...         ...      ...         ...       ...      ...
# 239  2022/1/1  0.008676  102.112497  281.933   89.992501  102.6863      2.9
# 240  2022/2/1  0.008652  102.519725  284.182   93.892176  103.6341      NaN
# 241  2022/3/1  0.008195         NaN  287.708         NaN  104.5853      NaN
# 242  2022/4/1  0.007711         NaN      NaN         NaN       NaN      NaN
# 243  2022/5/1  0.007685         NaN      NaN         NaN       NaN      NaN
#
# ...

# %%
import pandas as pd
import numpy as np
import os


from statsmodels.tsa.vector_ar.vecm import coint_johansen

import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 15
matplotlib.rcParams['xtick.labelsize'] = 20
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['text.color'] = 'k'
plt.rcParams["figure.figsize"] = [12,9]

# %%
d1.isnull().any() 
d1.isnull().sum()
# Out:
# DATE          0
# CNYUSD        7
# cpi_chn       4
# cpi_us        3
# iip_chn      19
# iip_us        3
# irr_chn       6
# irr_us        2
# m1_chn       42
# m1_us         3
# nt_us         4
# nt_chn        4
# tr_us         3
# tr_chn        5
# stock_us      3
# stock_chn     3
# dtype: int64

# %%
d1 = d1.fillna(d1.mean())

d1 = d1.dropna()

# %%
d1['m1_chn1'] = (d1['m1_chn'] / d1['CNYUSD']) / 1000000000
print((d1))
df = d1
# Out:
#          DATE    CNYUSD     cpi_chn      cpi_us     iip_chn      iip_us  \
# 0    2002/1/1  0.120824   71.061305  177.700000  118.600000   88.670600
# 1    2002/2/1  0.120824   71.842980  178.000000  102.700000   88.672300
# 2    2002/3/1  0.120811   70.909021  178.500000  110.900000   89.362400
# 3    2002/4/1  0.120812   70.696294  179.300000  112.100000   89.793300
# 4    2002/5/1  0.120824   70.484205  179.500000  112.900000   90.162900
# ..        ...       ...         ...         ...         ...         ...
# 241  2022/2/1  0.158328  114.334737  284.182000  111.011894  103.634100
# 242  2022/3/1  0.157575   91.668457  287.708000  111.011894  104.585300
# 243  2022/4/1  0.151343   91.668457  225.128111  111.011894   97.260676
# 244  2022/5/1  0.151345   91.668457  225.128111  111.011894   97.260676
# 245  2022/5/5  0.150297   91.668457  225.128111  111.011894   97.260676
#
#       irr_chn    irr_us        m1_chn         m1_us         nt_us  \
# ...

# %%
df['cpi_d'] = df['cpi_us'] - df['cpi_chn']
df['iip_d'] = df['iip_us'] - df['iip_chn']
df['irr_d'] = df['irr_us'] - df['irr_chn']
df['m1_d'] = df['m1_us'] - df['m1_chn1']
df['rsrv_d'] = df['tr_us'] - df['tr_chn']
df['stock_d'] = df['stock_us'] - df['stock_chn']
df['trade_d'] = df['nt_us'] - df['nt_chn']

# %%
import datetime as dt

df['month'] = pd.DatetimeIndex(df['DATE']).month
df['year'] = pd.DatetimeIndex(df['DATE']).year
df['Date'] = pd.to_datetime(df['DATE'])

# %%
y = df['CNYUSD']

plt.plot(df['Date'], y)
plt.title('Foreign Exchange Rate (CNYUSD)')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Foreign Exchange Rate (CNYUSD)')

# %%
for params in ['cpi_', 'iip_', 'irr_', 'm1_', 'tr_', 'stock_', 'nt_']:
        
    if params in ['reserves_', 'trade_']:
        plt.plot(df['Date'], df[params+'chn']/1000000000, label='China')
        plt.plot(df['Date'], df[params+'us']/1000000000, label='USA')
    else:
        plt.plot(df['Date'], df[params+'chn'], label='China')
        plt.plot(df['Date'], df[params+'us'], label='USA')
        
    if params == 'cpi_':
        plt.title('Consumer Price Index (CPI)')
    elif params == 'iip_':
        plt.title('Index of Industrial Production (IIP)')
    elif params == 'irr_':
        plt.title('Interest Rates (%)')
    elif params == 'm1_':
        plt.title('Money Supply ($ Billion)')
    elif params == 'tr_':
        plt.title('Reserves ($ Billion)')
    elif params == 'stock_':
        plt.title('Stock Index (Scaled)')
    elif params == 'nt_':
        plt.title('Net Exports ($ Billion)')
    plt.legend()
    # plt.savefig(params + '.png')
    plt.show()

# %% [markdown]
# # Data Transformation

# %%
df_d = df[['CNYUSD', 'cpi_d', 'iip_d', 'irr_d', 'm1_d', 'rsrv_d', 'stock_d', 'trade_d']]
y = df['CNYUSD']

#creating the train and validation set
train = df_d[:int(0.8*(len(df_d)))]
valid = df_d[int(0.8*(len(df_d))):]

#fit the model
from statsmodels.tsa.vector_ar.var_model import VAR

model = VAR(endog=train)
model_fit = model.fit()
prediction = model_fit.summary()
print(prediction)
# make prediction on validation
#prediction = model_fit.forecast(df['CNYUSD'], steps=len(valid))
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 06, May, 2022
# Time:                     19:53:42
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    102.234
# Nobs:                     195.000    HQIC:                   101.515
# Log likelihood:          -11991.6    FPE:                7.50252e+43
# AIC:                      101.026    Det(Omega_mle):     5.22929e+43
# --------------------------------------------------------------------
# Results for equation CNYUSD
# ...
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const              0.009691         0.009069            1.069           0.285
# L1.CNYUSD          0.866286         0.041535           20.857           0.000
# ...

# %%
mse = model_fit.mse(2)
print(mse)
# Out:
# [[[ 6.80198806e-06  6.47207965e-05  2.35237090e-05 -4.65111351e-05
#     4.82489844e+00 -1.74303401e+07  2.00213809e-03  3.38665138e+06]
#   [ 6.47207965e-05  5.41737603e-01 -4.31186115e-01  2.08403779e-03
#    -1.54756142e+02 -2.85957301e+09  3.42652074e-01  2.07834072e+09]
#   [ 2.35237090e-05 -4.31186115e-01  7.73768241e+00  1.61733636e-02
#    -5.11220694e+02  5.67500729e+09 -2.66115315e-01 -1.05540712e+10]
#   [-4.65111351e-05  2.08403779e-03  1.61733636e-02  2.85565996e-02
#    -1.83779113e+01  7.78288391e+08 -6.38639445e-02  9.86451457e+07]
#   [ 4.82489844e+00 -1.54756142e+02 -5.11220694e+02 -1.83779113e+01
#     1.44499052e+07 -2.06310955e+13  2.77317339e+03  1.17571718e+12]
#   [-1.74303401e+07 -2.85957301e+09  5.67500729e+09  7.78288391e+08
#    -2.06310955e+13  1.11412989e+21 -1.41780061e+10 -8.93707213e+19]
#   [ 2.00213809e-03  3.42652074e-01 -2.66115315e-01 -6.38639445e-02
#     2.77317339e+03 -1.41780061e+10  3.91909993e+01 -1.07080766e+10]
# ...

# %%
from sklearn.metrics import mean_squared_error

#converting predictions to dataframe
pred = pd.DataFrame(index=range(0,len(prediction)),columns=[df_d.columns])
for j in range(0,len(df_d.columns)):
    for i in range(0, len(prediction)):
        pred.iloc[i][j] = prediction[i][j]

#check rmse
for i in df_d.columns:
    print('rmse value for', i, 'is : ', np.sqrt(mean_squared_error(pred[i], valid[i])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_24848/2443516816.py in <module>
#       5 for j in range(0,len(df_d.columns)):
#       6     for i in range(0, 64):
# ----> 7         pred.iloc[i][j] = prediction[i][j]
#       8
#       9 #check rmse
#
# TypeError: 'VARSummary' object is not subscriptable

# %%
coint_johansen(df_d,-1,1).eig
# Out:
# array([0.37618895, 0.25736089, 0.19846805, 0.08049454, 0.03493417,
#        0.027498  , 0.01212198, 0.00054538])

# %% [markdown]
# # Blog

# %%
input_feature= df_d.iloc[:,:].values
input_data = input_feature

# %%
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler(feature_range=(0,1))
input_data[:,:] = sc.fit_transform(input_feature[:,:])

# %%
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler(feature_range=(0,1))
input_data = sc.fit_transform(df_d)

# %%
lookback= 3

test_size=int(.2 * len(df_d))
X=[]
y=[]
for i in range(len(df_d)-lookback-1):
    t=[]
    for j in range(0,lookback):
        
        t.append(input_data[[(i+j)], :])
    X.append(t)
    y.append(input_data[i+ lookback,0])

# %%
X, y= np.array(X), np.array(y)
X_test = X[-(test_size+lookback):]
X = X.reshape(X.shape[0],lookback, 8)
X_test = X_test.reshape(X_test.shape[0],lookback, 8)
print(X.shape)
print(X_test.shape)
# Out:
# (242, 3, 8)
# (52, 3, 8)

# %%
from keras import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(LSTM(units=30, return_sequences= True, input_shape=(X.shape[1],8)))
model.add(LSTM(units=30, return_sequences=True))
model.add(LSTM(units=30))
model.add(Dense(units=1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 3, 30)             4680
#
#  lstm_1 (LSTM)               (None, 3, 30)             7320
#
#  lstm_2 (LSTM)               (None, 30)                7320
#
#  dense (Dense)               (None, 1)                 31
#
# ...
# Total params: 19,351
# Trainable params: 19,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

# %%
hist = model.fit(X[:], y[:], epochs=50, batch_size=32, validation_split = 0.0, callbacks = [early])
# Out:
# Epoch 1/50
# ...
# 8/8 [==============================] - 5s 5ms/step - loss: 0.3317
# Epoch 2/50
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2231
# Epoch 3/50
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1247
# Epoch 4/50
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0920
# Epoch 5/50
# ...
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0708
# Epoch 6/50
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0509
# Epoch 7/50
# ...
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0333
# Epoch 8/50
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0192
# Epoch 9/50
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0121
# Epoch 10/50
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0111
# Epoch 11/50
# ...
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0105
# Epoch 12/50
# ...
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0098
# Epoch 13/50
# ...

# %%
predicted_value= model.predict(X_test)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 3, 30)             4680
#
#  lstm_1 (LSTM)               (None, 3, 30)             7320
#
#  lstm_2 (LSTM)               (None, 30)                7320
#
#  dense (Dense)               (None, 1)                 31
#
# ...
# Total params: 19,351
# Trainable params: 19,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(predicted_value, color= 'red')
plt.plot(input_data[-(test_size+(2*lookback)):-lookback,0], color='green')
plt.title("Opening price of stocks sold")
plt.xlabel("Time (latest-> oldest)")
plt.ylabel("Stock Opening Price")
plt.show()

# %%
copy_in = input_data.copy()

# %% [markdown]
# # other methods

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
#dataset = read_csv('pollution.csv', header=0, index_col=0)
values = df_d.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7, 8]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df_d.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_24848/3580337528.py in <module>
#      11 for group in groups:
#      12         pyplot.subplot(len(groups), 1, i)
# ---> 13         pyplot.plot(values[:, group])
#      14         pyplot.title(df_d.columns[group], y=0.5, loc='right')
#      15         i += 1
#
# IndexError: index 8 is out of bounds for axis 1 with size 8

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# load dataset
#dataset = read_csv('pollution.csv', header=0, index_col=0)
values = df_d.values
# integer encode direction
#encoder = LabelEncoder()
#values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.000337   0.005359   0.027478   0.327286   1.000000   1.000000
# 2   0.000337   0.000000   0.373027   0.434859   0.999511   0.998349
# 3   0.000045   0.015954   0.209835   0.432972   0.998330   0.997285
# 4   0.000067   0.027221   0.193122   0.437471   0.995102   0.995661
# 5   0.000337   0.031806   0.183769   0.437137   0.992194   0.994855
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.839191   0.856117  0.000337
# 2   0.522813   0.834472  0.000045
# 3   0.538023   0.850930  0.000067
# 4   0.531502   0.837464  0.000337
# 5   0.600238   0.837654  0.000135

# %%
# split into train and test sets
values = reframed.values
n_train_hours = int(0.9*len(df_d))
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (221, 1, 8) (221,) (24, 1, 8) (24,)

# %%
# design network
model = Sequential()
model.add(LSTM(20, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(4))
model.add(Dense(1))
#model.add(Dropout(0.2))
model.compile(loss='mae', optimizer='adam')
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=[early])
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.title('Training Process for LSTM RNN')
pyplot.xlabel('Epochs')
pyplot.ylabel('Loss/ Error')
# pyplot.savefig('LSTM_Training.png')
# Out:
# Epoch 1/100
# 4/4 - 2s - loss: 0.4685 - val_loss: 0.6046 - 2s/epoch - 521ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 0.4561 - val_loss: 0.5835 - 46ms/epoch - 12ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 0.4449 - val_loss: 0.5610 - 57ms/epoch - 14ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 0.4336 - val_loss: 0.5378 - 70ms/epoch - 17ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 0.4224 - val_loss: 0.5142 - 52ms/epoch - 13ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 0.4112 - val_loss: 0.4901 - 54ms/epoch - 14ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 0.3998 - val_loss: 0.4656 - 71ms/epoch - 18ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 0.3885 - val_loss: 0.4406 - 37ms/epoch - 9ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 0.3771 - val_loss: 0.4152 - 43ms/epoch - 11ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.3655 - val_loss: 0.3893 - 49ms/epoch - 12ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.3539 - val_loss: 0.3629 - 32ms/epoch - 8ms/step
# Epoch 12/100
# ...

# %%
from sklearn.metrics import mean_squared_error

# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.174

# %%
plt.plot(inv_yhat, color= 'red')
plt.plot(inv_y, color='green')
plt.title("Predictions by LSTM Model")
plt.xlabel("Months (2002.2-> 2022.1)")
plt.ylabel("CNY/USD Exchange Rate")
plt.show()

# %%
accuracy = 100 - (np.mean(abs(inv_y - inv_yhat)/inv_y))*100
print('Accuracy= '+ str(accuracy)+ ' %')
# Out:
# Accuracy= 78.31248044967651 %

# %% [markdown]
# # SVM Model

# %%
reframed
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1     0.000337   0.005359   0.027478   0.327286   1.000000   1.000000
# 2     0.000337   0.000000   0.373027   0.434859   0.999511   0.998349
# 3     0.000045   0.015954   0.209835   0.432972   0.998330   0.997285
# 4     0.000067   0.027221   0.193122   0.437471   0.995102   0.995661
# 5     0.000337   0.031806   0.183769   0.437137   0.992194   0.994855
# ..         ...        ...        ...        ...        ...        ...
# 241   0.824399   0.691019   0.496936   0.070988   0.726938   0.223642
# 242   0.844015   0.708594   0.517532   0.037756   0.729868   0.471620
# 243   0.827076   1.000000   0.538202   0.061418   0.727697   0.470927
# 244   0.686883   0.303759   0.379035   0.086656   0.655646   0.435099
# 245   0.686928   0.303759   0.379035   0.272873   0.655652   0.435099
#
#      var7(t-1)  var8(t-1)   var1(t)
# 1     0.839191   0.856117  0.000337
# 2     0.522813   0.834472  0.000045
# ...

# %%
# split into train and test sets
values = reframed.values
n_train_hours = int(0.9*len(df_d))
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# %%
train_y.shape
# Out:
# (221,)

# %%
from sklearn.svm import SVR
import numpy as np

clf = SVR(gamma='scale', C=1.0, epsilon=0.2)
clf.fit(train_X, train_y)
# Out:
# SVR(epsilon=0.2)

# %%
from sklearn.model_selection import GridSearchCV 
  
# defining parameter range 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3) 
  
# fitting the model for grid search 
grid.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.420 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.938 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.504 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.247 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-1.110 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.328 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.381 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.160 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-6.730 total time=   0.0s
# ...

# %%
# print best parameter after tuning 
print(grid.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# SVR(C=1000, gamma=0.001)

# %%
grid_predictions = grid.predict(test_X)

# %%
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

print('Forecast Accuracy of: CNYUSD')
accuracy_prod = forecast_accuracy(grid_predictions, test_y)
for k, v in accuracy_prod.items():
    print(str(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: CNYUSD
# mape :  0.1038
# me :  -0.0777
# mae :  0.079
# mpe :  -0.1014
# rmse :  0.0891
# corr :  0.9141
# minmax :  0.1038

# %%
grid_predictions = grid_predictions.reshape((24,1))

# %%
from sklearn.metrics import mean_squared_error

# make a prediction
#yhat = model.predict(test_X)
#test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_pred_svm = np.concatenate((grid_predictions, test_X[:, 1:]), axis=1)
inv_pred_svm = scaler.inverse_transform(inv_pred_svm)
inv_pred_svm = inv_pred_svm[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_pred_svm))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.089

# %%
train_X
# Out:
# array([[3.3743505e-04, 5.3589349e-03, 2.7478021e-02, ..., 1.0000000e+00,
#         8.3919102e-01, 8.5611659e-01],
#        [3.3743505e-04, 0.0000000e+00, 3.7302741e-01, ..., 9.9834913e-01,
#         5.2281332e-01, 8.3447212e-01],
#        [4.4991339e-05, 1.5953695e-02, 2.0983472e-01, ..., 9.9728495e-01,
#         5.3802282e-01, 8.5092998e-01],
#        ...,
#        [4.5108315e-01, 4.4177642e-01, 6.4629519e-01, ..., 2.4615765e-01,
#         1.5447667e-01, 5.3479874e-01],
#        [4.6174613e-01, 4.2986086e-01, 2.4980551e-01, ..., 2.3788868e-01,
#         6.5320730e-01, 4.8678064e-01],
#        [4.3461633e-01, 4.3820509e-01, 2.7461287e-01, ..., 2.3603195e-01,
#         6.3298458e-01, 4.4199935e-01]], dtype=float32)

# %%
plt.plot(inv_pred_svm, color= 'red')
plt.plot(inv_y, color='green')
plt.title("Opening price of stocks sold")
plt.xlabel("Time (latest-> oldest)")
plt.ylabel("Stock Opening Price")
plt.show()

# %%
from sklearn.ensemble import ExtraTreesRegressor
#from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectFromModel
#iris = load_iris()
X, y = train_X, train_y
#X.shape

clf = ExtraTreesRegressor(n_estimators=50)
clf = clf.fit(X, y)
print(clf.feature_importances_)

model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
X_new.shape
# Out:
# [0.54107934 0.07796916 0.00300828 0.03880003 0.10523727 0.22696298
#  0.00430557 0.00263737]
# (221, 2)

# %%
x = ('CNYUSD', 'CPI', 'IIP', 'Interest', 'Money_S', 'Reserve', 'Stock', 'Trade')
y = clf.feature_importances_

plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Parametric Difference: x(USA) - x(CNY)')
plt.ylabel('Feature Importance (0 -> 1)')
plt.title('Feature Score')
#plt.show()
#plt.savefig('ft_score.png')
# Out:
# Text(0.5, 1.0, 'Feature Score')

# %%
accuracy = 100 - (np.mean(abs(inv_y - inv_pred_svm)/inv_y))*100
print('Accuracy= '+ str(accuracy)+ ' %')
# Out:
# Accuracy= 89.61501257527281 %

# %% [markdown]
# # VAR

# %%
#checking stationarity

from statsmodels.tsa.vector_ar.vecm import coint_johansen
#since the test works for only 12 variables, I have randomly dropped
#in the next iteration, I would drop another and check the eigenvalues
johan_test_temp = df_d
coint_johansen(johan_test_temp,-1,1).eig
# Out:
# array([3.88273188e-01, 2.21095083e-01, 1.21581443e-01, 8.09840649e-02,
#        3.44979125e-02, 2.79087741e-02, 1.27239446e-02, 2.16349661e-04])

# %%
#creating the train and validation set
train = df_d[:-int(0.1*(len(df_d)))]
valid = df_d[-int(0.1*(len(df_d))):]

#fit the model
from statsmodels.tsa.vector_ar.var_model import VAR

model = VAR(endog=train)
model_fit = model.fit()

# make prediction on validation
# prediction = model_fit.forecast(model_fit.y, steps=len(valid))
prediction = model_fit.forecast()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_24848/807462565.py in <module>
#      11 # make prediction on validation
#      12 # prediction = model_fit.forecast(model_fit.y, steps=len(valid))
# ---> 13 prediction = model_fit.forecast()
#
# TypeError: forecast() missing 2 required positional arguments: 'y' and 'steps'
